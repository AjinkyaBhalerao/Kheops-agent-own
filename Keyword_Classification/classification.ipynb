# %%
import fitz
import re
from pdfminer.high_level import extract_pages
from pdfminer.layout import *
import textwrap
import math
import json
import sys

pdf_path = "civil-code.pdf"
#starting_words = ["Titre", "Title", "Chapitre", "Chapter", "Section", "Sous-section","Sub-section", "Paragraphe","Paragraph" , "Livre", "Book" ]

# %%
doc = fitz.open(pdf_path)
font = {}
i = 0

file = open("font.txt", 'w', encoding='utf-8') 

for page in doc:
    blocks =  page.get_text("dict", flags=11)["blocks"]
    for block in blocks:
        for l in block["lines"]:  # iterate through the text lines
            for s in l["spans"]:  # iterate through the text spans
                font[i] = [s["text"], s["font"], s["size"], s["bbox"]]
                i += 1

doc.close()

# %%
font
# Out:
# {0: ['THAT KIND OF GUY',
#   'JosefinSans',
#   21.2592830657959,
#   (202.26751708984375,
#    81.56968688964844,
#    392.718017578125,
#    102.82896423339844)],
#  1: ['STEPHANIE ARCHER',
#   'JosefinSans',
#   21.2592830657959,
#   (197.21392822265625, 80.81925964355469, 397.783203125, 102.07854461669922)],
#  2: ['This is a work of fiction. Names, characters, places, and incidents are products of',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    79.2289810180664,
#    474.0730285644531,
#    91.69438934326172)],
#  3: ['the author’s imagination or are used fictitiously and are not to be construed as real.',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    91.98604583740234,
#    480.7625427246094,
#    104.45145416259766)],
#  4: ['Any resemblance to actual events, locales, organizations, or persons, living or dead,',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    104.74312591552734,
#    485.4222412109375,
#    117.20853424072266)],
#  5: ['is entirely coincidental.',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    117.50019073486328,
#    213.37835693359375,
#    129.96559143066406)],
#  6: ['That Kind of Guy. Copyright © 2021 by Stephanie Archer. All rights reserved. No',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    136.26058959960938,
#    479.107177734375,
#    148.72598266601562)],
#  7: ['part of this book may be reproduced in any form or by any electronic or mechanical',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    149.01766967773438,
#    485.32720947265625,
#    161.48306274414062)],
#  8: ['means, including information storage and retrieval systems, without written',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    161.77474975585938,
#    448.8026428222656,
#    174.24014282226562)],
#  9: ['permission from the author, except for the use of brief quotations in a book review.',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    174.53179931640625,
#    481.31707763671875,
#    186.9971923828125)],
#  10: ['Cover design by Outlined With Love Designs.',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828,
#    192.5417938232422,
#    316.7219543457031,
#    205.00718688964844)],
#  11: ['ISBN 978-1-7779780-0-6',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (108.01996612548828, 211.30218505859375, 224.63458251953125, 223.767578125)],
#  12: ['For Tim',
#   'TimesNewRomanPS-ItalicMT',
#   15.008317947387695,
#   (273.0997314453125,
#    79.63752746582031,
#    321.8939514160156,
#    96.25807189941406)],
#  13: ['Contents',
#   'JosefinSans',
#   21.2592830657959,
#   (260.964111328125,
#    80.81925964355469,
#    334.0279541015625,
#    102.07854461669922)],
#  14: ['1. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    154.27056884765625,
#    138.2241973876953,
#    166.7359619140625)],
#  15: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    154.27056884765625,
#    168.52166748046875,
#    166.7359619140625)],
#  16: ['2. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    174.53179931640625,
#    138.2241973876953,
#    186.9971923828125)],
#  17: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    174.53179931640625,
#    176.87249755859375,
#    186.9971923828125)],
#  18: ['3. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    194.7930450439453,
#    138.2241973876953,
#    207.25843811035156)],
#  19: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    194.7930450439453,
#    168.52166748046875,
#    207.25843811035156)],
#  20: ['4. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    215.0542755126953,
#    138.2241973876953,
#    227.51966857910156)],
#  21: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    215.0542755126953,
#    176.87249755859375,
#    227.51966857910156)],
#  22: ['5. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    235.3155059814453,
#    138.2241973876953,
#    247.78089904785156)],
#  23: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    235.3155059814453,
#    168.52166748046875,
#    247.78089904785156)],
#  24: ['6. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    255.57672119140625,
#    138.2241973876953,
#    268.0421142578125)],
#  25: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    255.57672119140625,
#    176.87249755859375,
#    268.0421142578125)],
#  26: ['7. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    275.83795166015625,
#    138.2241973876953,
#    288.3033447265625)],
#  27: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    275.83795166015625,
#    168.52166748046875,
#    288.3033447265625)],
#  28: ['8. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    296.09918212890625,
#    138.2241973876953,
#    308.5645751953125)],
#  29: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    296.09918212890625,
#    176.87249755859375,
#    308.5645751953125)],
#  30: ['9. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    316.36041259765625,
#    138.2241973876953,
#    328.8258056640625)],
#  31: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (141.22586059570312,
#    316.36041259765625,
#    168.52166748046875,
#    328.8258056640625)],
#  32: ['10. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    336.62164306640625,
#    143.85232543945312,
#    349.0870361328125)],
#  33: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    336.62164306640625,
#    182.5006103515625,
#    349.0870361328125)],
#  34: ['11. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    356.88287353515625,
#    143.43460083007812,
#    369.3482666015625)],
#  35: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.431884765625,
#    356.88287353515625,
#    182.07850646972656,
#    369.3482666015625)],
#  36: ['12. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    377.14410400390625,
#    143.85232543945312,
#    389.6094970703125)],
#  37: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    377.14410400390625,
#    174.1497802734375,
#    389.6094970703125)],
#  38: ['13. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    397.40533447265625,
#    143.85232543945312,
#    409.8707275390625)],
#  39: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    397.40533447265625,
#    174.1497802734375,
#    409.8707275390625)],
#  40: ['14. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    417.66656494140625,
#    143.85232543945312,
#    430.1319580078125)],
#  41: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    417.66656494140625,
#    174.1497802734375,
#    430.1319580078125)],
#  42: ['15. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    437.92779541015625,
#    143.85232543945312,
#    450.3931884765625)],
#  43: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    437.92779541015625,
#    182.5006103515625,
#    450.3931884765625)],
#  44: ['16. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    458.18902587890625,
#    143.85232543945312,
#    470.6544189453125)],
#  45: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    458.18902587890625,
#    174.1497802734375,
#    470.6544189453125)],
#  46: ['17. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    478.45025634765625,
#    143.85232543945312,
#    490.9156494140625)],
#  47: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    478.45025634765625,
#    174.1497802734375,
#    490.9156494140625)],
#  48: ['18. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    498.71148681640625,
#    143.85232543945312,
#    511.1768798828125)],
#  49: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    498.71148681640625,
#    174.1497802734375,
#    511.1768798828125)],
#  50: ['19. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    518.9727172851562,
#    143.85232543945312,
#    531.4381103515625)],
#  51: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    518.9727172851562,
#    182.5006103515625,
#    531.4381103515625)],
#  52: ['20. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    539.2339477539062,
#    143.85232543945312,
#    551.6993408203125)],
#  53: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    539.2339477539062,
#    182.5006103515625,
#    551.6993408203125)],
#  54: ['21. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    559.4951782226562,
#    143.85232543945312,
#    571.9605712890625)],
#  55: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    559.4951782226562,
#    174.1497802734375,
#    571.9605712890625)],
#  56: ['22. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    579.7564086914062,
#    143.85232543945312,
#    592.2218017578125)],
#  57: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    579.7564086914062,
#    174.1497802734375,
#    592.2218017578125)],
#  58: ['23. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    600.0176391601562,
#    143.85232543945312,
#    612.4830322265625)],
#  59: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    600.0176391601562,
#    174.1497802734375,
#    612.4830322265625)],
#  60: ['24. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    620.2788696289062,
#    143.85232543945312,
#    632.7442626953125)],
#  61: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    620.2788696289062,
#    174.1497802734375,
#    632.7442626953125)],
#  62: ['25. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    640.5401000976562,
#    143.85232543945312,
#    653.0054931640625)],
#  63: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    640.5401000976562,
#    182.5006103515625,
#    653.0054931640625)],
#  64: ['26. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    660.8013305664062,
#    143.85232543945312,
#    673.2667236328125)],
#  65: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    660.8013305664062,
#    174.1497802734375,
#    673.2667236328125)],
#  66: ['27. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    681.0625610351562,
#    143.85232543945312,
#    693.5279541015625)],
#  67: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    681.0625610351562,
#    174.1497802734375,
#    693.5279541015625)],
#  68: ['28. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    701.3237915039062,
#    143.85232543945312,
#    713.7891845703125)],
#  69: ['Avery',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    701.3237915039062,
#    174.1497802734375,
#    713.7891845703125)],
#  70: ['29. ',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    721.5850219726562,
#    143.85232543945312,
#    734.0504150390625)],
#  71: ['Emmett',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (146.85398864746094,
#    721.5850219726562,
#    182.5006103515625,
#    734.0504150390625)],
#  72: ['Epilogue',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    741.8462524414062,
#    167.61251831054688,
#    754.3116455078125)],
#  73: ['Want a bonus spicy scene with Emmett and Avery?',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781, 71.72478485107422, 357.7939453125, 84.19019317626953)],
#  74: ['Acknowledgments',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    91.98601531982422,
#    211.38031005859375,
#    104.45142364501953)],
#  75: ['About the Author',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    112.24724578857422,
#    206.3808135986328,
#    124.71265411376953)],
#  76: ['Also by Stephanie Archer',
#   'TimesNewRomanPSMT',
#   11.25623893737793,
#   (126.96797180175781,
#    132.50848388671875,
#    242.9449462890625,
#    144.973876953125)],
#  77: ['1',
#   'JosefinSans',
#   11.25623893737793,
#   (295.8115539550781,
#    87.57112884521484,
#    299.1659240722656,
#    98.82736206054688)],
#  78: ['Avery',
#   'JosefinSans',
#   21.2592830657959,
#   (273.76806640625, 89.07383728027344, 321.21630859375, 110.33311462402344)],
#  79: ['“AVERY,',
#   'JosefinSans',
#   15.008317947387695,
#   (108.01996612548828,
#    284.36773681640625,
#    159.27330017089844,
#    299.37603759765625)],
#  80: [' Table Four doesn’t like their entrées, and they want to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (159.27102661132812,
#    282.2498474121094,
#    486.8223571777344,
#    298.8703918457031)],
#  81: ['speak to the manager.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    299.5093994140625,
#    244.70704650878906,
#    316.12994384765625)],
#  82: ['I looked up from the desk of my tiny office. The',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    324.27313232421875,
#    486.80059814453125,
#    340.8936767578125)],
#  83: ['restaurant’s bartender, Max, leaned against the doorframe in',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    341.5326843261719,
#    486.7377014160156,
#    358.1532287597656)],
#  84: ['the black jeans and black t-shirt that the serving staff always',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    358.7922668457031,
#    486.84393310546875,
#    375.4128112792969)],
#  85: ['wore.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 376.05181884765625, 141.773681640625, 392.67236328125)],
#  86: ['“Is something wrong with the food?” I asked. We didn’t',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688, 400.8155517578125, 486.919921875, 417.43609619140625)],
#  87: ['often get complaints. Our chef was incredible. The kitchen',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    418.0751037597656,
#    486.8650207519531,
#    434.6956481933594)],
#  88: ['staff was a great team. The entire staff was top tier, from',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    435.3346862792969,
#    486.3626403808594,
#    451.9552307128906)],
#  89: ['servers to hosts to dishwashers. I had hired most of them.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 452.59423828125, 452.3408203125, 469.21478271484375)],
#  90: ['Max shook his head.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688, 477.35797119140625, 254.7563018798828, 493.978515625)],
#  91: ['I leaned back in my chair. “Tourists?”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    502.1217346191406,
#    357.4403991699219,
#    518.7422485351562)],
#  92: ['He nodded.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    526.8854370117188,
#    199.72079467773438,
#    543.5059204101562)],
#  93: ['I stood. “It’s okay, I’ve got it.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    551.649169921875,
#    314.21075439453125,
#    568.2696533203125)],
#  94: ['“Are you going to comp their meals?” He stepped back',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    576.4129028320312,
#    486.7046203613281,
#    593.0333862304688)],
#  95: ['and followed me from my office to the restaurant.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 593.6724853515625, 407.41845703125, 610.29296875)],
#  96: ['I smiled at him over my shoulder. “Sure am.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    618.4362182617188,
#    403.1294860839844,
#    635.0567016601562)],
#  97: ['“Why?”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    643.1998901367188,
#    179.69741821289062,
#    659.8203735351562)],
#  98: ['Just before we turned the corner into the restaurant, I',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    667.963623046875,
#    486.36004638671875,
#    684.5841064453125)],
#  99: ['stopped. I had hired Max last summer as a server and noticed',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    685.2232055664062,
#    486.8797302246094,
#    701.8436889648438)],
#  100: ['our bartender teaching him how to make different drinks after',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    702.4827880859375,
#    486.57659912109375,
#    719.103271484375)],
#  101: ['the restaurant closed. He was in his early twenties, had lots of',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    719.7423706054688,
#    486.79241943359375,
#    736.3628540039062)],
#  102: ['energy, and was eager to learn, so I asked the bartender to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    737.0018920898438,
#    486.2554931640625,
#    753.6223754882812)],
#  103: ['spend a few minutes training him every shift until Max was',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    72.13333129882812,
#    486.65875244140625,
#    88.75387573242188)],
#  104: ['able to work full shifts behind the bar. I’d never admit this to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    89.39291381835938,
#    486.32147216796875,
#    106.01345825195312)],
#  105: ['the rest of the staff but Max was my favorite. He was great',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    106.65249633789062,
#    486.26336669921875,
#    123.27304077148438)],
#  106: ['with customers, everyone liked working with him, and he had',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    123.91201782226562,
#    486.90167236328125,
#    140.53256225585938)],
#  107: ['a genuine interest in learning the restaurant business. Tonight,',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    141.17160034179688,
#    486.33721923828125,
#    157.79214477539062)],
#  108: ['he was stepping in to help with a few tables.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    158.43118286132812,
#    373.9673767089844,
#    175.05172729492188)],
#  109: ['“Max, our purpose is to deliver a delightful experience to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    183.19491577148438,
#    486.78753662109375,
#    199.81546020507812)],
#  110: ['every customer who walks through that door. This is where',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    200.45443725585938,
#    486.4886474609375,
#    217.07498168945312)],
#  111: ['people come for a break, to celebrate, to catch up with old',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    217.71401977539062,
#    486.8359069824219,
#    234.33456420898438)],
#  112: ['friends or to try a new dish.” In the hallway before the dining',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    234.97360229492188,
#    486.54241943359375,
#    251.59414672851562)],
#  113: ['room, I could already hear the warm ambient hum of the full',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    252.23318481445312,
#    486.5251159667969,
#    268.8537292480469)],
#  114: ['restaurant, filled with people eating and talking and laughing.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    269.4927062988281,
#    477.3446960449219,
#    286.1132507324219)],
#  115: ['That sound? It made my heart happy. It made me feel like I',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    294.2564392089844,
#    486.6239013671875,
#    310.8769836425781)],
#  116: ['was doing something good for the world.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    311.5160217285156,
#    355.22198486328125,
#    328.1365661621094)],
#  117: ['“We want every single person who walks through that door',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    336.2797546386719,
#    486.5391845703125,
#    352.9002990722656)],
#  118: ['to have the best damn meal while they visit Queen’s Cove, and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    353.5393371582031,
#    486.3916320800781,
#    370.1598815917969)],
#  119: ['if I lose a hundred bucks to comp their meals,” I shrugged,',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    370.7988586425781,
#    486.4668273925781,
#    387.4194030761719)],
#  120: ['“that’s okay with me. It’s not worth it to piss off the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    388.0583801269531,
#    486.257080078125,
#    404.6789245605469)],
#  121: ['customers.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    405.3180236816406,
#    179.2921905517578,
#    421.9385681152344)],
#  122: ['It wasn’t ',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    430.0816955566406,
#    189.94972229003906,
#    446.7022399902344)],
#  123: ['my',
#   'TimesNewRomanPS-ItalicMT',
#   15.008317947387695,
#   (192.94593811035156, 430.0816955566406, 210.443359375, 446.7022399902344)],
#  124: [' hundred bucks to lose, since it wasn’t my',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (210.4400177001953, 430.0816955566406, 486.365478515625, 446.7022399902344)],
#  125: ['restaurant. I was just the manager. One day, though.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    447.3413391113281,
#    418.8002014160156,
#    463.9618835449219)],
#  126: ['He raised an eyebrow, and I grinned at his skepticism.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    472.1050109863281,
#    455.07965087890625,
#    488.7255554199219)],
#  127: ['“Maybe they’re entitled,” I told him. “Or maybe they’re',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    496.8688049316406,
#    486.7676086425781,
#    513.4893188476562)],
#  128: ['just having a bad day. Maybe they got a flat tire on the way',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    514.1283569335938,
#    486.3201904296875,
#    530.7488403320312)],
#  129: ['into town, they got to their hotel late, and they’re starving.” I',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    531.3878784179688,
#    486.7147216796875,
#    548.0083618164062)],
#  130: ['gave him my most convincing smile. “Maybe we can turn their',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    548.6475219726562,
#    486.93511962890625,
#    565.2680053710938)],
#  131: ['day around. We’re going to kill them with kindness.” I',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    565.9070434570312,
#    486.70294189453125,
#    582.5275268554688)],
#  132: ['narrowed my eyes at him. “We’re going to absolutely ',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    583.1665649414062,
#    456.084716796875,
#    599.7870483398438)],
#  133: ['bury',
#   'TimesNewRomanPS-ItalicMT',
#   15.008317947387695,
#   (458.9918212890625,
#    583.1665649414062,
#    486.49981689453125,
#    599.7870483398438)],
#  134: ['them with our sparkling personalities.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    600.4262084960938,
#    341.8772888183594,
#    617.0466918945312)],
#  135: ['“This is morbid. You always take this analogy too far.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    625.1898803710938,
#    460.39300537109375,
#    641.8103637695312)],
#  136: ['“Once they see how passionate we are?” I put my fist to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    649.9536743164062,
#    486.3625793457031,
#    666.5741577148438)],
#  137: ['my chest in mock-agony. “They’re going to be rolled out the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    667.2131958007812,
#    486.7406921386719,
#    683.8336791992188)],
#  138: ['door in bodybags.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    684.4727172851562,
#    222.65121459960938,
#    701.0932006835938)],
#  139: ['He pointed at me. “Yep, there it is. Alright, you’re the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    709.2365112304688,
#    486.383056640625,
#    725.8569946289062)],
#  140: ['boss. Thanks for handling it.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    726.4960327148438,
#    286.4365539550781,
#    743.1165161132812)],
#  141: ['“Anytime. I’ve got your back.” I walked out into the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    72.13333129882812,
#    486.5545654296875,
#    88.75387573242188)],
#  142: ['restaurant, taking in the packed house.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    89.39285278320312,
#    338.5177307128906,
#    106.01339721679688)],
#  143: ['It was just after eight at night, and every table was full.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    114.15664672851562,
#    486.5495910644531,
#    130.77719116210938)],
#  144: ['The restaurant overlooked the harbor of Queen’s Cove. On a',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    131.41616821289062,
#    486.437744140625,
#    148.03671264648438)],
#  145: ['clear night, the sunset would wash brilliant pinks and oranges',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    148.67568969726562,
#    486.4084777832031,
#    165.29623413085938)],
#  146: ['and yellows splashed across the sky, but tonight, clouds rolled',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    165.93533325195312,
#    486.9593505859375,
#    182.55587768554688)],
#  147: ['in and rain began to trickle down. It had been sunny all day,',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    183.19485473632812,
#    486.6531066894531,
#    199.81539916992188)],
#  148: ['but once in a while, these summer storms rolled in. I chewed',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    200.45437622070312,
#    486.9740295410156,
#    217.07492065429688)],
#  149: ['my lip, glancing around at the busy restaurant. Hopefully it',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    217.71401977539062,
#    486.81695556640625,
#    234.33456420898438)],
#  150: ['was just a little rain tonight, and no wind.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    234.97354125976562,
#    357.3231506347656,
#    251.59408569335938)],
#  151: ['“Hi, I’m Avery Adams, the manager of The Arbutus,” I',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    259.7373352050781,
#    486.92437744140625,
#    276.3578796386719)],
#  152: ['introduced myself to the unhappy-looking family of four. The',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    276.9968566894531,
#    486.8167724609375,
#    293.6174011230469)],
#  153: ['two boys were sulking and fidgeting, one was trying to pull',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    294.2563781738281,
#    486.2657775878906,
#    310.8769226074219)],
#  154: ['the others’ hair, and they wore the expressions of kids who had',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    311.5160217285156,
#    486.7126159667969,
#    328.1365661621094)],
#  155: ['just been told off. “Let me grab these plates out of your way.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    328.7755432128906,
#    486.7850341796875,
#    345.3960876464844)],
#  156: ['I passed the plates to a passing server before placing the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 346.0350646972656, 486.7802734375, 362.6556091308594)],
#  157: ['coloring pages and crayons on the table in front of the boys.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    363.2947082519531,
#    486.8823547363281,
#    379.9152526855469)],
#  158: ['They immediately stopped fighting with each other and turned',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    380.5542297363281,
#    486.882080078125,
#    397.1747741699219)],
#  159: ['to the pages.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    397.8138732910156,
#    183.46678161621094,
#    414.4344177246094)],
#  160: ['The parents were in their late thirties, and just as I had',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688, 422.5775451660156, 486.45458984375, 439.1980895996094)],
#  161: ['suspected, they looked exhausted and irritated. Both of their',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    439.8370666503906,
#    486.9697570800781,
#    456.4576110839844)],
#  162: ['jaws were set like they expected a fight.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    457.0967102050781,
#    348.0930480957031,
#    473.7172546386719)],
#  163: ['“I am so sorry that your meals were not as you expected.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    481.8603820800781,
#    486.4639892578125,
#    498.4809265136719)],
#  164: ['Wow,” I said, my gaze catching on the woman’s bright red',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    499.1199035644531,
#    486.28155517578125,
#    515.7404174804688)],
#  165: ['shoulder. “That sunburn looks like it hurts. Can I bring you',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    516.3795776367188,
#    486.440673828125,
#    533.0000610351562)],
#  166: ['some aloe for that?”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    533.6390991210938,
#    229.29991149902344,
#    550.2595825195312)],
#  167: ['She blinked, and her irritation lifted a fraction. “Um, sure.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    558.4028930664062,
#    486.77752685546875,
#    575.0233764648438)],
#  168: ['She hesitated. “We stopped by the general store, but they were',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    575.6624145507812,
#    486.4813232421875,
#    592.2828979492188)],
#  169: ['closed.” She gestured outside where the rain was coming',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 592.9219360351562, 486.9697265625, 609.5424194335938)],
#  170: ['down harder, and a grumpy look came over her face. “And',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    610.1815795898438,
#    486.3172302246094,
#    626.8020629882812)],
#  171: ['now it’s raining on our holiday.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    627.4411010742188,
#    302.9595642089844,
#    644.0615844726562)],
#  172: ['“They closed early tonight because it’s the owners’',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    652.2048950195312,
#    486.4569091796875,
#    668.8253784179688)],
#  173: ['wedding anniversary. I’ll go get you some aloe, but in the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    669.4644165039062,
#    486.8403015136719,
#    686.0848999023438)],
#  174: ['meantime, are there any other entrées that look interesting to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    686.7239379882812,
#    486.51055908203125,
#    703.3444213867188)],
#  175: ['you? They’ll be comped this evening, for the inconvenience,”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    703.9835815429688,
#    486.4468688964844,
#    720.6040649414062)],
#  176: ['I said with a sweet smile.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    721.2431030273438,
#    259.75408935546875,
#    737.8635864257812)],
#  177: ['The husband looked confused and then looked at his menu.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    72.13333129882812,
#    486.5148010253906,
#    88.75387573242188)],
#  178: ['“We were wishing we ordered the pizzas. The Margherita and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    89.39285278320312,
#    486.5938720703125,
#    106.01339721679688)],
#  179: ['the meatball pizzas.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    106.65237426757812,
#    233.47222900390625,
#    123.27291870117188)],
#  180: ['I nodded. “Absolutely, great choices. Can I get you a',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    131.41604614257812,
#    486.2427673339844,
#    148.03659057617188)],
#  181: ['couple drinks? The blackberry gin smash is on special tonight.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    148.67581176757812,
#    486.8995666503906,
#    165.29635620117188)],
#  182: ['The gin is made at a local distillery here in Queen’s Cove, and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    165.93533325195312,
#    486.36962890625,
#    182.55587768554688)],
#  183: ['the blackberries are local and organic.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    183.19485473632812,
#    342.75921630859375,
#    199.81539916992188)],
#  184: ['The wife nodded, watching her sons across the table, busy',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    207.95852661132812,
#    486.96734619140625,
#    224.57907104492188)],
#  185: ['with coloring, and more importantly, quiet. “That would be',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    225.21804809570312,
#    486.6751403808594,
#    241.83859252929688)],
#  186: ['wonderful.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    242.47756958007812,
#    180.11764526367188,
#    259.0981140136719)],
#  187: ['“Sure thing. Let’s make your vacation a good one, shall',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    267.2414855957031,
#    486.8945007324219,
#    283.8620300292969)],
#  188: ['we?” I scribbled their order on a paper, handed it to the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    284.5010070800781,
#    486.4123229980469,
#    301.1215515136719)],
#  189: ['kitchen and bar, and slipped back to my office to grab one of',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    301.7605285644531,
#    486.9038391113281,
#    318.3810729980469)],
#  190: ['the travel bottles of aloe sitting in the mini fridge. Max had',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    319.0200500488281,
#    486.3988952636719,
#    335.6405944824219)],
#  191: ['laughed at me when he saw this, but he stopped laughing when',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    336.2795715332031,
#    486.5147399902344,
#    352.9001159667969)],
#  192: ['he saw time and time again how a stupid little bottle of aloe',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    353.5393371582031,
#    486.72686767578125,
#    370.1598815917969)],
#  193: ['could turn his table around.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    370.7988586425781,
#    272.67620849609375,
#    387.4194030761719)],
#  194: ['“Drop this at Table Four, would you,” I said to him as he',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    395.5625305175781,
#    486.518310546875,
#    412.1830749511719)],
#  195: ['passed. “And comp their food and drinks.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    412.8220520019531,
#    364.7799987792969,
#    429.4425964355469)],
#  196: ['He gave me a thumbs up and kept walking.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    437.5857238769531,
#    390.2214050292969,
#    454.2062683105469)],
#  197: ['“Thanks, Max,” I called after him.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    462.3496398925781,
#    337.2570495605469,
#    478.9701843261719)],
#  198: ['I watched from the edge of the restaurant as he dropped the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    487.1133117675781,
#    486.8726806640625,
#    503.7338562011719)],
#  199: ['bottle of aloe off at the table. The woman looked so relieved,',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 504.3728332519531, 486.84375, 520.9933471679688)],
#  200: ['and I felt like punching the air. I loved flipping customers like',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 521.6323852539062, 486.64208984375, 538.2528686523438)],
#  201: ['that. Walking up to that table, they were tired and grouchy, but',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    538.8919067382812,
#    486.4421081542969,
#    555.5123901367188)],
#  202: ['now the couple were laughing and talking, their kids were',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    556.1516723632812,
#    486.4593811035156,
#    572.7721557617188)],
#  203: ['immersed in coloring, and their vacation was off to a great',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    573.4111938476562,
#    486.84381103515625,
#    590.0316772460938)],
#  204: ['start. I had completely turned their night around. I loved my',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    590.6707153320312,
#    486.8872375488281,
#    607.2911987304688)],
#  205: ['job.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    607.9302368164062,
#    130.95266723632812,
#    624.5507202148438)],
#  206: ['I scanned the restaurant. Tonight was a mix of locals and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    632.6939086914062,
#    486.65985107421875,
#    649.3143920898438)],
#  207: ['tourists. The owners of the general store were having their',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    649.9536743164062,
#    486.6224365234375,
#    666.5741577148438)],
#  208: ['anniversary dinner at Table Two. The elementary school',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    667.2131958007812,
#    486.5006103515625,
#    683.8336791992188)],
#  209: ['principal and her husband were at Table Six. The mayor, his',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    684.4727172851562,
#    486.9722595214844,
#    701.0932006835938)],
#  210: ['wife, and their two children were at Table Eight. Their family',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    701.7322387695312,
#    486.88568115234375,
#    718.3527221679688)],
#  211: ['was always polite, friendly, and perfectly well-behaved. The',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    718.9917602539062,
#    486.95159912109375,
#    735.6122436523438)],
#  212: ['kids never wanted to color, they just sat quietly and smiled at',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    736.2512817382812,
#    486.3008117675781,
#    752.8717651367188)],
#  213: ['everyone like little angels, and it creeped me out. The owner',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    72.13320922851562,
#    486.4228210449219,
#    88.75375366210938)],
#  214: ['of a local construction company sat at Table Eleven with one',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    89.39273071289062,
#    486.4729309082031,
#    106.01327514648438)],
#  215: ['of his clients. I snorted to myself, watching Emmett Rhodes',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    106.65225219726562,
#    486.50604248046875,
#    123.27279663085938)],
#  216: ['schmooze and smile and ooze charm all over the table.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    123.91201782226562,
#    486.695068359375,
#    140.53256225585938)],
#  217: ['Emmett was Mr. Popular, knew everyone in town, was all up',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    141.17153930664062,
#    486.56085205078125,
#    157.79208374023438)],
#  218: ['in everyone’s business, and was well aware of exactly how',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    158.43106079101562,
#    486.9550476074219,
#    175.05160522460938)],
#  219: ['handsome he was.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    175.69058227539062,
#    217.64073181152344,
#    192.31112670898438)],
#  220: ['At Table Twelve was the owner of a couple local',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    200.45425415039062,
#    486.9402160644531,
#    217.07479858398438)],
#  221: ['restaurants, Chuck, and his wife. His wife was sneering at the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    217.71401977539062,
#    486.71728515625,
#    234.33456420898438)],
#  222: ['food, and Chuck was looking around before making notes in a',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    234.97354125976562,
#    486.39666748046875,
#    251.59408569335938)],
#  223: ['notebook. I rolled my eyes. I had a few tips I could give him,',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    252.23306274414062,
#    486.8121337890625,
#    268.8536071777344)],
#  224: ['but he wouldn’t listen.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    269.4925842285156,
#    242.81898498535156,
#    286.1131286621094)],
#  225: ['The restaurants Chuck owned catered to tourists because',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688, 294.2562561035156, 486.7822265625, 310.8768005371094)],
#  226: ['the locals knew better than to go there. The food wasn’t',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    311.5160217285156,
#    486.6839599609375,
#    328.1365661621094)],
#  227: ['exactly bad, it just had that taste like it was made a few days',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    328.7755432128906,
#    486.3696594238281,
#    345.3960876464844)],
#  228: ['ago, frozen, thawed, and reheated. Even that wasn’t enough to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    346.0350646972656,
#    486.8197937011719,
#    362.6556091308594)],
#  229: ['earn my disdain, though. It was the way he treated his staff.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    363.2945861816406,
#    486.3584289550781,
#    379.9151306152344)],
#  230: ['The male staff wore black t-shirts and jeans, just like here at',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    380.5541076660156,
#    486.749267578125,
#    397.1746520996094)],
#  231: ['The Arbutus, but the female staff were required to wear mini-',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    397.8136291503906,
#    486.4922180175781,
#    414.4341735839844)],
#  232: ['skirts, low cut tops, and high heels. Heels, for eight-hour',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    415.0733947753906,
#    486.84356689453125,
#    431.6939392089844)],
#  233: ['serving shifts. The thought made my blood boil. He hired kids',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    432.3329162597656,
#    486.7685852050781,
#    448.9534606933594)],
#  234: ['straight out of school who didn’t know any better or who had',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    449.5924377441406,
#    486.3124694824219,
#    466.2129821777344)],
#  235: ['no other options, so they put up with it. There were rumors',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    466.8519592285156,
#    486.66864013671875,
#    483.4725036621094)],
#  236: ['that he took a cut of their tips, too.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 484.1114807128906, 314.78955078125, 500.7320251464844)],
#  237: ['“Table Twelve giving you any trouble tonight?” I asked',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    508.8753967285156,
#    486.86492919921875,
#    525.4959106445312)],
#  238: ['Max as he shook a drinks shaker.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    526.1349487304688,
#    306.8435363769531,
#    542.7554321289062)],
#  239: ['“Nope. They’ve been on their best behavior.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    550.8986206054688,
#    403.0785217285156,
#    567.5191040039062)],
#  240: ['“Good.” I watched as Chuck studied the chandelier. What',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    575.6622924804688,
#    486.27960205078125,
#    592.2827758789062)],
#  241: ['was he up to?',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    592.9218139648438,
#    190.12820434570312,
#    609.5422973632812)],
#  242: ['I had been the manager of The Arbutus for two years, but I',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    617.6857299804688,
#    486.60772705078125,
#    634.3062133789062)],
#  243: ['had been working here for five years, since the day I set foot',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    634.9452514648438,
#    486.84063720703125,
#    651.5657348632812)],
#  244: ['in the tiny seaside town of Queen’s Cove. Located on',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    652.2047729492188,
#    486.7366638183594,
#    668.8252563476562)],
#  245: ['Vancouver Island, Canada, wedged between the Pacific Ocean',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    669.4642944335938,
#    486.4054260253906,
#    686.0847778320312)],
#  246: ['and the Pacific Northwest rainforest, this little town housed',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    686.7238159179688,
#    486.98431396484375,
#    703.3442993164062)],
#  247: ['about two thousand residents, but because of its breathtaking',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    703.9835815429688,
#    486.3259582519531,
#    720.6040649414062)],
#  248: ['beaches, dense, mossy forests, relaxed small-town vibes, and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    721.2431030273438,
#    486.3843078613281,
#    737.8635864257812)],
#  249: ['the best surfing in the country, it welcomed over a million',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    738.5026245117188,
#    486.6877746582031,
#    755.1231079101562)],
#  250: ['tourists during the summer months. It was early May, and the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 72.13296508789062, 486.8623046875, 88.75350952148438)],
#  251: ['tourists were starting to trickle in. By July, we’d be in full',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    89.39273071289062,
#    486.6144714355469,
#    106.01327514648438)],
#  252: ['swing.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    106.65225219726562,
#    147.62692260742188,
#    123.27279663085938)],
#  253: ['I was born and raised in Vancouver, but Queen’s Cove was',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    131.41592407226562,
#    486.78631591796875,
#    148.03646850585938)],
#  254: ['my home now. Five years ago, I came here on vacation by',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    148.67544555664062,
#    486.8085021972656,
#    165.29598999023438)],
#  255: ['myself, and after going for a nice dinner at the restaurant with',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    165.93496704101562,
#    486.5105285644531,
#    182.55551147460938)],
#  256: ['the best view, I fell in love. Giant windows that overlooked the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    183.19473266601562,
#    486.67034912109375,
#    199.81527709960938)],
#  257: ['picturesque cove and beach, oak flooring, and vaulted ceilings',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    200.45425415039062,
#    486.77520751953125,
#    217.07479858398438)],
#  258: ['with original beams. A menu that was modern, unpretentious,',
# ...
#  918: ['“People are moving away from town,” I told him. “The',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    391.0599670410156,
#    486.7193603515625,
#    407.6805114746094)],
#  919: ['town spent money on a new tourist center two years ago, but',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    408.3192443847656,
#    486.5593566894531,
#    424.9397888183594)],
#  920: ['we can’t spend money on the residents themselves?”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    425.5790100097656,
#    424.1026611328125,
#    442.1995544433594)],
#  921: ['Isaac shrugged again and shook his head. “What can I say,',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    450.3426818847656,
#    486.54620361328125,
#    466.9632263183594)],
#  922: ['Emmett? My hands are tied. Just consider it part of our small-',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    467.6019592285156,
#    486.5668029785156,
#    484.2225036621094)],
#  923: ['town charm.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    484.8617248535156,
#    189.7079620361328,
#    501.4822692871094)],
#  924: ['It was like he didn’t want to fix it. My chest was tight with',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    509.6253967285156,
#    486.6600646972656,
#    526.2459106445312)],
#  925: ['irritation. The role of the mayor was to take care of the town',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    526.8851928710938,
#    486.7630920410156,
#    543.5056762695312)],
#  926: ['and work hard for the people who lived here. Isaac didn’t seem',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    544.1444702148438,
#    486.9920349121094,
#    560.7649536132812)],
#  927: ['like he really cared about the town or the people. I swallowed',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    561.4042358398438,
#    486.3475341796875,
#    578.0247192382812)],
#  928: ['thickly and stood.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    578.6640014648438,
#    215.16433715820312,
#    595.2844848632812)],
#  929: ['“Thanks for your time.” My voice sounded curt.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    603.4276733398438,
#    420.2230224609375,
#    620.0481567382812)],
#  930: ['I spent the rest of the morning in my office with the door',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    628.1913452148438,
#    486.29559326171875,
#    644.8118286132812)],
#  931: ['closed, catching up on paperwork, emails, and client calls. I',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    645.4506225585938,
#    486.36004638671875,
#    662.0711059570312)],
#  932: ['kept my head down and worked to keep my mind off Will and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    662.7103881835938,
#    486.687744140625,
#    679.3308715820312)],
#  933: ['Isaac and the power outages.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    679.9701538085938,
#    280.975830078125,
#    696.5906372070312)],
#  934: ['“HEY, DIV,”',
#   'JosefinSans',
#   15.008317947387695,
#   (108.01996612548828,
#    74.25108337402344,
#    183.0764923095703,
#    89.25940704345703)],
#  935: [' I called out my open office door later that',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (183.07327270507812,
#    72.13320922851562,
#    486.87786865234375,
#    88.75375366210938)],
#  936: ['afternoon.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    89.39248657226562,
#    169.28390502929688,
#    106.01303100585938)],
#  937: ['He appeared at my office door, phone poised and ready to',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    114.15615844726562,
#    486.64398193359375,
#    130.77670288085938)],
#  938: ['go. “Yes?”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    131.41592407226562,
#    172.35711669921875,
#    148.03646850585938)],
#  939: ['Div, short for Divyanshu, was in his mid-twenties and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    156.17959594726562,
#    486.9690856933594,
#    172.80014038085938)],
#  940: ['wore a full suit every day. I’d made it clear that he didn’t have',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    173.43936157226562,
#    486.34039306640625,
#    190.05990600585938)],
#  941: ['to dress up for work, but the guy insisted. Div was a good',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    190.69863891601562,
#    486.3556213378906,
#    207.31918334960938)],
#  942: ['assistant—punctual, memory like a steel trap, tech-savvy, and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    207.95840454101562,
#    486.31536865234375,
#    224.57894897460938)],
#  943: ['often knew my schedule without looking at my calendar. He',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    225.21817016601562,
#    486.3018493652344,
#    241.83871459960938)],
#  944: ['could wear whatever he wanted, as far as I was concerned.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    242.47744750976562,
#    459.739990234375,
#    259.0979919433594)],
#  945: ['“Did Holden submit his invoices yet?” I asked him.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    267.2411193847656,
#    440.2591247558594,
#    283.8616638183594)],
#  946: ['Div pointed to a corner of my tidy desk. “Right there.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    292.0047912597656,
#    459.0022277832031,
#    308.6253356933594)],
#  947: ['“Ah. Thanks.” I scooped up the papers and shuffled',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    316.7684631347656,
#    486.9509582519531,
#    333.3890075683594)],
#  948: ['through them until I found the one I was looking for.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 334.0282287597656, 424.396484375, 350.6487731933594)],
#  949: ['“I’m ordering lunch.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    358.7919006347656,
#    260.98248291015625,
#    375.4124450683594)],
#  950: ['“Nothing for me, thanks. Hey, can you send Cal at',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    383.5555725097656,
#    486.2670593261719,
#    400.1761169433594)],
#  951: ['SparkPro a bottle of the whiskey he likes?” We still had six',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    400.8153381347656,
#    486.5330505371094,
#    417.4358825683594)],
#  952: ['months left on the community center project. Staying on Cal’s',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    418.0746154785156,
#    486.7440185546875,
#    434.6951599121094)],
#  953: ['good side would prevent misunderstandings like this morning.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    435.3343811035156,
#    482.387451171875,
#    451.9549255371094)],
#  954: ['Div made a note before disappearing back to his desk.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    460.0980529785156,
#    455.6426696777344,
#    476.7185974121094)],
#  955: ['On the bottom of the pile of Holden’s invoices sat a',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    484.8617248535156,
#    486.418701171875,
#    501.4822692871094)],
#  956: ['business magazine I had done an interview with a couple',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    502.1214904785156,
#    486.9599304199219,
#    518.7420043945312)],
#  957: ['months ago. I cringed at my image on the cover, leaning',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 519.3807983398438, 486.37109375, 536.0012817382812)],
#  958: ['casually against the railing of one of our custom-built homes.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    536.6405639648438,
#    486.9794616699219,
#    553.2610473632812)],
#  959: ['Holden never wanted to be involved with this kind of thing, so',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    553.9003295898438,
#    486.2535705566406,
#    570.5208129882812)],
#  960: ['I took care of it. I didn’t want to be involved either, but it was',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    571.1596069335938,
#    486.34515380859375,
#    587.7800903320312)],
#  961: ['good for our reputation and good for business. We had',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    588.4193725585938,
#    486.2875061035156,
#    605.0398559570312)],
#  962: ['employees to keep busy and mouths to feed.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    605.6786499023438,
#    373.9673767089844,
#    622.2991333007812)],
#  963: ['“Your mom wanted ten copies,” Div told me. He didn’t',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    630.4428100585938,
#    486.6267395019531,
#    647.0632934570312)],
#  964: ['dare laugh but his eyes gleamed.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    647.7020874023438,
#    303.923583984375,
#    664.3225708007812)],
#  965: ['I rolled my eyes with a snort and tossed the magazine in',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    672.4657592773438,
#    486.47686767578125,
#    689.0862426757812)],
#  966: ['the recycling as Div left to answer the phone.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    689.7255249023438,
#    380.1958312988281,
#    706.3460083007812)],
#  967: ['My email pinged with a newsletter from the town',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    714.4891967773438,
#    486.6590270996094,
#    731.1096801757812)],
#  968: ['journalist. He was retired but periodically sent a condensed',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828, 731.7489624023438, 486.78955078125, 748.3694458007812)],
#  969: ['version of the town events and news. I enjoyed reading it and',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    72.13272094726562,
#    486.9646911621094,
#    88.75326538085938)],
#  970: ['staying up to date on what was happening in my town.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    89.39248657226562,
#    435.2613525390625,
#    106.01303100585938)],
#  971: ['Will and his family were mentioned. My gaze snagged on',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    114.15615844726562,
#    486.531494140625,
#    130.77670288085938)],
#  972: ['a picture of Kara, holding a stuffed toy that I bought her. A',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    131.41543579101562,
#    486.7762756347656,
#    148.03598022460938)],
#  973: ['panda. I grinned. She looked so damn cute, missing that front',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    148.67520141601562,
#    486.6587219238281,
#    165.29574584960938)],
#  974: ['tooth. My chest tightened as I realized that this was my',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    165.93447875976562,
#    486.6542053222656,
#    182.55502319335938)],
#  975: ['relationship with Will and his family for the foreseeable future',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    183.19424438476562,
#    486.759521484375,
#    199.81478881835938)],
#  976: ['—photos, texts, emails, and FaceTime.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    200.45401000976562,
#    341.7481384277344,
#    217.07455444335938)],
#  977: ['It wasn’t right, Kara growing up in the city three hours',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    225.21768188476562,
#    486.8758544921875,
#    241.83822631835938)],
#  978: ['away. Both Will and Nat’s parents lived here, all her friends at',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    242.47695922851562,
#    486.4502258300781,
#    259.0975036621094)],
#  979: ['school were here, and my heart broke every time I thought',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    259.7367248535156,
#    486.35528564453125,
#    276.3572692871094)],
#  980: ['about her not having the carefree, small-town childhood that',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    276.9960021972656,
#    486.7825622558594,
#    293.6165466308594)],
#  981: ['Will and I had had.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    294.2557678222656,
#    222.87576293945312,
#    310.8763122558594)],
#  982: ['I thought about Nat and I felt a pang for her. Kara was her',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    319.0194396972656,
#    486.4399719238281,
#    335.6399841308594)],
#  983: ['world, and she was trying so hard to create a great life for her.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    336.2792053222656,
#    486.9258728027344,
#    352.8997497558594)],
#  984: ['Although she hadn’t spoken to me about this, I knew moving',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    353.5384826660156,
#    486.252197265625,
#    370.1590270996094)],
#  985: ['was hard on her. She didn’t want to leave either, but it was the',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    370.7982482910156,
#    486.2628479003906,
#    387.4187927246094)],
#  986: ['right choice for their family.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    388.0580139160156,
#    277.4937744140625,
#    404.6785583496094)],
#  987: ['I had to fix this.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    412.8216857910156,
#    226.00035095214844,
#    429.4422302246094)],
#  988: ['I kept skimming the newsletter, and something caught my',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    437.5853576660156,
#    486.9810485839844,
#    454.2059020996094)],
#  989: ['eye.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    454.8446350097656,
#    132.6035919189453,
#    471.4651794433594)],
#  990: ['Mayoral election scheduled for July 2.',
#   'TimesNewRomanPS-ItalicMT',
#   15.008317947387695,
#   (130.53244018554688,
#    479.6083068847656,
#    362.2909240722656,
#    496.2288513183594)],
#  991: ['I frowned, trying to remember the last election we had, but',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688, 504.3724670410156, 486.94775390625, 520.9929809570312)],
#  992: ['came up with nothing.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    521.6317749023438,
#    242.25436401367188,
#    538.2522583007812)],
#  993: ['“Hey, Div,” I shouted out the door.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    546.3954467773438,
#    339.07330322265625,
#    563.0159301757812)],
#  994: ['“What?” he called back, appearing at the door moments',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    571.1591186523438,
#    486.25555419921875,
#    587.7796020507812)],
#  995: ['later.',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    588.4188842773438,
#    137.60423278808594,
#    605.0393676757812)],
#  996: ['“When was the last mayoral election?”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    613.1825561523438,
#    364.34478759765625,
#    629.8030395507812)],
#  997: ['“About four years ago.” He shrugged. “This town has a',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    637.9462280273438,
#    486.7997741699219,
#    654.5667114257812)],
#  998: ['really low voter turnout.”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (108.01996612548828,
#    655.2059936523438,
#    260.5772399902344,
#    671.8264770507812)],
#  999: ['“Why?”',
#   'TimesNewRomanPSMT',
#   15.008317947387695,
#   (130.53244018554688,
#    679.9696655273438,
#    179.69741821289062,
#    696.5901489257812)],
#  ...}

# %%
with open("font.txt", "w", encoding='utf-8') as f:
    f.write(str(font))

f.close()

# %%
#def comp_fontsize(dictionary, string):
#    keys = list(dictionary.keys())
#    
#    for i in range(len(keys) - 1):
#        curr_key = keys[i]
#        next_key = keys[i+1]
#    
#        if dictionary[curr_key][0] == string and dictionary[curr_key][2] == dictionary[next_key][2]:
#            # Continue iterating if font sizes are the same
#            continue
#        elif dictionary[curr_key][0] == string:
#            return False
#    
#    return True
#

# %%
def get_footers(fitz_doc):
    footers = []
    for page in fitz_doc:
        data = page.get_text("blocks")
        h = page.rect.height

        for l in data:
            if l[1] > 0.90*h:
                text = l[4]
                footers.append(text[:-1]) # remove the newline character at end of footer

    return footers

def extract_sentences_with_starting_words(pdf_path, starting_words):
    doc = fitz.open(pdf_path)
    word_sentences = [[] for _ in range(len(starting_words))]
    current_word = None
    previous_line_empty = False
    previous_line_word = None

    # Get footers to check later if line is a footer
    footers = get_footers(doc)

    for page in doc:
        text = page.get_text()
        lines = text.splitlines()
        for line in lines:
            if line.strip():  # Check if the line is not empty
                # Check if the line starts with any of the starting words
                for i, word in enumerate(starting_words):
                    if line.lower().startswith(word.lower() + ' ') and line[0].isupper():
                        current_word = i
                        word_sentences[current_word].append(line.strip())
                        previous_line_word = i
                        break
                else:
                    # Append the line to the current sentence if a starting word is detected in the previous line
                    if current_word is not None and line not in footers:
                        word_sentences[current_word][-1] += ' ' + line.strip()
                        previous_line_word = current_word
            elif previous_line_word is not None and not previous_line_empty:
                # End the sentence if the current line is empty and the previous line wasn't empty
                current_word = None
                previous_line_word = None

            previous_line_empty = not line.strip()  # Update the flag for the previous line

    doc.close()
    return word_sentences

# %%
def concat_strings(input_list):
    result_list = []
    temp_string = ""
    prev_attributes = None

    for item in input_list:
        text, font, size, float_val = item
        attributes = (font, size, float_val)

        if attributes == prev_attributes: # and not re.search(r'Bold', font, re.IGNORECASE):
            if (text[0].isupper() and re.search(r'Bold', font, re.IGNORECASE)) or text[0].isupper():
                temp_string = text
            else:
                temp_string += " " + text
        else:
            if temp_string:
                result_list.append([temp_string.strip()] + list(prev_attributes))
            temp_string = text
            prev_attributes = attributes

    # Append the last concatenated string
    if temp_string:
        result_list.append([temp_string.strip()] + list(prev_attributes))

    return result_list

# %%
def extract_text_by_fontsize(pdf_url):
    extracted_text = ""
    curr_font = None
    curr_size = None
    font_attr = []

    for page_layout in extract_pages(pdf_url):
        for element in page_layout:
            if isinstance(element, LTTextBox):
                for line in element:
                    thisline = []
                    if isinstance(line, LTTextLine):
                        for char in line:
                            if isinstance(char, LTChar):
                                ft = char.fontname
                                sz = math.ceil(char.size)
                                x = char.bbox[0]
    
                                #if ft != curr_font or sz != curr_size:
    
                                l = line.get_text()
                                thisline.append(l[:-1])
                                thisline.append(ft)
                                thisline.append(sz)
                                thisline.append(x)
                                font_attr.append(thisline)        
                            break

    result_list = concat_strings(font_attr)
    return result_list

# %%
def classify_text(font_name, text, font_size, x):
  # Classification rules here based on font_name, font_size, and y (position)
  if (re.search(r'Bold', font_name, re.IGNORECASE) and font_size > 14) or font_size > 14 or (font_size > 14 and x > 125) or text.isupper():  # Threshold based on PDF
    return "Titre"
  elif re.search(r'Bold', font_name, re.IGNORECASE) and font_size > 13:
    return "Section"
  elif font_size > 8:
    return "Paragraphe"
  else:
    return "Footer"


def process_pdf(pdf_text):
  l2 = []
  for line_attr in pdf_text:
    
    text = line_attr[0]
    font_name = line_attr[1]
    font_size = line_attr[2]
    x = line_attr[3]
    category = classify_text(font_name, text, font_size, x)
    # Do something with the classified text and category
    #print(f"{text}, Category: {category}")
    map = (category, text)
    l2.append(map)
  return l2

# %%
def comp(l1, l2):
    # Convert list1 to a set of sentences for efficient comparison
    set1 = set([(category, sentence) for category, sentence in l1])

    combined_sentences = l1[:]
    
    temp = []
    for c, s in l1:
        temp.append(s)
    
    for category, sentence in l2:
    
        if sentence not in temp:
            combined_sentences.append((category, sentence))

    def sort_key(item):
    # Get the first key in the dictionary and return it
        return next(iter(item))

    # Sort the list of dictionaries
    sorted_data = sorted(combined_sentences, key=sort_key)
    
    return sorted_data

# %%
def make_map(suchi):
    naksha = {}
    for i, (c, s)  in enumerate(suchi):
        naksha[i] = {"Category": c, "Text":s}

    unique_map = {}
    for key, value in naksha.items():
        if value not in unique_map.values():
            unique_map[key] = value

    res = {}
    i = 0
    for key, value in unique_map.items():
        res[i] = value
        i += 1
    
    return res

# %%
if __name__ == "__main__":
    #if len(sys.argv) != 2:
    #    print("Command: python main.py <pdf path>")
    #    sys.exit(1)
    #pdf_path = "C:\\Users\\AKSHITA RAI\\Downloads\\Catalogue des cours Formation d'ingénieur centralien - 2022-11-29 (1).pdf"
    pdf_path = "civil-code.pdf"

    starting_words = ["Titre", "Title", "Chapitre", "Chapter", "Section", "Sous-section","Sub-section", "Paragraphe","Paragraph", "Article", "Livre", "Book" ]
    
    # Extract sentences with specified starting words
    word_sentences = extract_sentences_with_starting_words(pdf_path, starting_words)

    l1 = []
    for i, word in enumerate(starting_words):
        for sentence in word_sentences[i]:
            map = (word, sentence)
            l1.append(map)

    pdf_text = extract_text_by_fontsize(pdf_path)
    l2 = process_pdf(pdf_text)

    compare = comp(l1, l2)
    naksha = make_map(compare)

    outfile = open("output_uni.json", "w", encoding = 'utf-8') 
    json.dump(naksha, outfile,indent=2, ensure_ascii=False)
    outfile.close()
